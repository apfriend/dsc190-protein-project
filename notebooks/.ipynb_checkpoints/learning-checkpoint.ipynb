# %% [markdown]
# # Graph Learning Methods

# %%
# %load_ext autoreload
# %autoreload 2
# %cd '../src'
# %matplotlib inline
# Out:
# /media/apfriend/sabrent/ucsd/classes/dsc190/project/src

# %%
import os
import sys
import re
import warnings
import gudhi as gd
import pandas as pd
import numpy as np
import nglview as nv
from Bio.PDB import PDBParser
from Bio.PDB.PDBExceptions import PDBConstructionWarning
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import eda as eda
import pda as pda

#hide discontinuous chain warnings
warnings.simplefilter('ignore', PDBConstructionWarning)

# %% [markdown]
# ## Decision Tree Classifier
#
# Since virus proteins seem to have more complex structures than compared to insulin or other basic molecules of life, a decision tree may classify data parsed thus far. Use a radius of 4.

# %%
point_cloud_data_fp='../data/out/birth_death_data.csv'

point_cloud_df=pd.read_csv(point_cloud_data_fp)
point_cloud_df=point_cloud_df.loc[point_cloud_df.max_radius==4]
lookup_tag=pda.get_protein_tag_table()
point_cloud_df['protein_name']=point_cloud_df.protein_tag.apply(lambda x : lookup_tag[x])
point_cloud_df
# Out:
#    protein_tag  num_atoms  num_chains  betti_0  betti_1  max_radius  \
# 1         1pid        810           4       29       52           4
# 9         2rmu       6541           4        2      938           4
# 17        1trz        919           4       18      103           4
# 25        4ajx       4921          12        1       39           4
# 33        4iyf        722           2        1        2           4
# 41        1H2C       1187           2        2      160           4
# 49        3IOL       1130           2        3      106           4
# 57        1IR3       2653           2        1      327           4
# 65        1IRK       2574           1        1      297           4
# 73        6VXX      23694          18        1     3012           4
# 81        6crz      25909          22        1     2917           4
# 89        3cji       6521           4        5      857           4
#
#     num_vertices  num_simplices         protein_name
# 1            810          13066       Bovine-Insulin
# 9           6541         123603          Common-Cold
# 17           919          15966    Designer-Insulins
# 25          4921         270048    Designer-Insulins
# 33           722          39947    Designer-Insulins
# 41          1187          21335                Ebola
# 49          1130          21643             Glucagon
# 57          2653          50884     Insulin-Receptor
# 65          2574          50565     Insulin-Receptor
# 73         23694         434394     Sars-Cov-2-Spike
# 81         25909         468374       Sars-Cov-Spike
# 89          6521         123568  Seneca-Valley-Virus
